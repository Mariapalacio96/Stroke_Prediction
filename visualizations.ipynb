# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# Load cleaned stroke dataset
file_path = "Resources/stroke_cleaned.csv"
stroke_df = pd.read_csv(file_path)
stroke_df.head(10)
# Out:
#       ID  Gender   Age  Hypertension  HeartDisease EverMarried           Work  \
# 0   9046    Male  67.0             0             1         Yes        Private
# 1  31112    Male  80.0             0             1         Yes        Private
# 2  60182  Female  49.0             0             0         Yes        Private
# 3   1665  Female  79.0             1             0         Yes  Self-employed
# 4  56669    Male  81.0             0             0         Yes        Private
# 5  53882    Male  74.0             1             1         Yes        Private
# 6  10434  Female  69.0             0             0          No        Private
# 7  60491  Female  78.0             0             0         Yes        Private
# 8  12109  Female  81.0             1             0         Yes        Private
# 9  12095  Female  61.0             0             1         Yes       Govt_job
#
#   Residence  Glucose   BMI          Smoking  Stroke
# 0     Urban   228.69  36.6  formerly smoked       0
# ...

# %%
# Change Hypertension values from 0/1 to strings
stroke_df['Hypertension'] = stroke_df['Hypertension'].replace([0,1],['no hypertension','hypertension'])

stroke_df.head(10)
# Out:
#       ID  Gender   Age     Hypertension  HeartDisease EverMarried  \
# 0   9046    Male  67.0  no hypertension             1         Yes
# 1  31112    Male  80.0  no hypertension             1         Yes
# 2  60182  Female  49.0  no hypertension             0         Yes
# 3   1665  Female  79.0     hypertension             0         Yes
# 4  56669    Male  81.0  no hypertension             0         Yes
# 5  53882    Male  74.0     hypertension             1         Yes
# 6  10434  Female  69.0  no hypertension             0          No
# 7  60491  Female  78.0  no hypertension             0         Yes
# 8  12109  Female  81.0     hypertension             0         Yes
# 9  12095  Female  61.0  no hypertension             1         Yes
#
#             Work Residence  Glucose   BMI          Smoking  Stroke
# 0        Private     Urban   228.69  36.6  formerly smoked       0
# 1        Private     Rural   105.92  32.5     never smoked       0
# ...

# %%
# Change Heart Disease values from 0/1 to strings
stroke_df['HeartDisease'] = stroke_df['HeartDisease'].replace([0,1],['no heart disease','heart disease'])

stroke_df.head(10)
# Out:
#       ID  Gender   Age     Hypertension      HeartDisease EverMarried  \
# 0   9046    Male  67.0  no hypertension     heart disease         Yes
# 1  31112    Male  80.0  no hypertension     heart disease         Yes
# 2  60182  Female  49.0  no hypertension  no heart disease         Yes
# 3   1665  Female  79.0     hypertension  no heart disease         Yes
# 4  56669    Male  81.0  no hypertension  no heart disease         Yes
# 5  53882    Male  74.0     hypertension     heart disease         Yes
# 6  10434  Female  69.0  no hypertension  no heart disease          No
# 7  60491  Female  78.0  no hypertension  no heart disease         Yes
# 8  12109  Female  81.0     hypertension  no heart disease         Yes
# 9  12095  Female  61.0  no hypertension     heart disease         Yes
#
#             Work Residence  Glucose   BMI          Smoking  Stroke
# 0        Private     Urban   228.69  36.6  formerly smoked       0
# ...

# %%
# Change Stroke values from 0/1 to strings
stroke_df['Stroke'] = stroke_df['Stroke'].replace([0,1],['no stroke','stroke'])

stroke_df.head(10)
# Out:
#       ID  Gender   Age     Hypertension      HeartDisease EverMarried  \
# 0   9046    Male  67.0  no hypertension     heart disease         Yes
# 1  31112    Male  80.0  no hypertension     heart disease         Yes
# 2  60182  Female  49.0  no hypertension  no heart disease         Yes
# 3   1665  Female  79.0     hypertension  no heart disease         Yes
# 4  56669    Male  81.0  no hypertension  no heart disease         Yes
# 5  53882    Male  74.0     hypertension     heart disease         Yes
# 6  10434  Female  69.0  no hypertension  no heart disease          No
# 7  60491  Female  78.0  no hypertension  no heart disease         Yes
# 8  12109  Female  81.0     hypertension  no heart disease         Yes
# 9  12095  Female  61.0  no hypertension     heart disease         Yes
#
#             Work Residence  Glucose   BMI          Smoking     Stroke
# 0        Private     Urban   228.69  36.6  formerly smoked  no stroke
# ...

# %%
# Pie chart showing Gender breakdown
colors = ["magenta", "lightblue"]
fig, ax = plt.subplots(figsize=(8,8))
ax.pie(stroke_df["Gender"].value_counts(),
    labels=stroke_df["Gender"].value_counts(),
    autopct='%.1f%%',
    colors=colors,
    shadow=True,
    startangle=90,
    counterclock=False)
plt.legend(['Female','Male'], loc="best")
plt.title("Stroke Dataset Gender Breakdown", bbox={'facecolor':'0.8', 'pad':5})

plt.show

# Save figure
plt.savefig('Resources/demo_gender.png')

# %%
# Distribution plot showing Age breakdown
sns.displot(stroke_df["Age"], bins=16).set(title='Stroke Dataset Age Breakdown')

# Save figure
plt.savefig('Resources/demo_age.png')

# %%
# Pie chart showing Hypertension breakdown
colors = ["grey", "red"]
fig, ax = plt.subplots(figsize=(8,8))
ax.pie(stroke_df["Hypertension"].value_counts(),
    labels=stroke_df["Hypertension"].value_counts(),
    autopct='%.1f%%',
    colors=colors,
    shadow=True,
    startangle=90,
    counterclock=False)
plt.legend(['No Hypertension','Hypertension'], loc="best")
plt.title("Stroke Dataset Hypertension Breakdown", bbox={'facecolor':'0.8', 'pad':5})

plt.show

# Save figure
plt.savefig('Resources/demo_hypertension.png')

# %%
# Pie chart showing Heart Disease breakdown
colors = ["grey", "red"]
fig, ax = plt.subplots(figsize=(8,8))
ax.pie(stroke_df["HeartDisease"].value_counts(),
    labels=stroke_df["HeartDisease"].value_counts(),
    autopct='%.1f%%',
    colors=colors,
    shadow=True,
    startangle=90,
    counterclock=False)
plt.legend(['No Heart Disease','Heart Disease'], loc="best")
plt.title("Stroke Dataset Heart Disease Breakdown", bbox={'facecolor':'0.8', 'pad':5})

plt.show

# Save figure
plt.savefig('Resources/demo_heartdisease.png')

# %%
# Pie chart showing Ever Married breakdown
colors = ["grey", "yellow"]
fig, ax = plt.subplots(figsize=(8,8))
ax.pie(stroke_df["EverMarried"].value_counts(),
    labels=stroke_df["EverMarried"].value_counts(),
    autopct='%.1f%%',
    colors=colors,
    shadow=True,
    startangle=90,
    counterclock=False)
plt.legend(['Ever Married','Never Married'], loc="best")
plt.title("Stroke Dataset Ever Married Breakdown", bbox={'facecolor':'0.8', 'pad':5})

plt.show

# Save figure
plt.savefig('Resources/demo_evermarried.png')

# %%
# Countplot showing Work breakdown
sns.countplot(x ='Work', data = stroke_df, palette="bright")

# Save figure
plt.savefig('Resources/demo_work.png')

# %%
# Pie chart showing Residence breakdown
colors = ["grey", "lightgreen"]
fig, ax = plt.subplots(figsize=(8,8))
ax.pie(stroke_df["Residence"].value_counts(),
    labels=stroke_df["Residence"].value_counts(),
    autopct='%.1f%%',
    colors=colors,
    shadow=True,
    startangle=90,
    counterclock=False)
plt.legend(['Urban','Rural'], loc="best")
plt.title("Stroke Dataset Residence Breakdown", bbox={'facecolor':'0.8', 'pad':5})

plt.show

# Save figure
plt.savefig('Resources/demo_residence.png')

# %%
# Distribution plot showing Glucose breakdown
sns.displot(stroke_df["Glucose"], bins=[50,75,100,125,150,175,200,225,250]).set(title='Stroke Dataset Glucose Breakdown')

# Save figure
plt.savefig('Resources/demo_glucose.png')

# %%
# Distribution plot showing BMI breakdown
sns.displot(stroke_df["BMI"], bins=[0,18.5,25,29.9,40,50,60,70,80,90,100]).set(title='Stroke Dataset BMI Breakdown')

# Save figure
plt.savefig('Resources/demo_bmi.png')

# %%
# Countplot showing Smoking breakdown
sns.countplot(x ='Smoking', data = stroke_df, palette="bright")

# Save figure
plt.savefig('Resources/demo_smoking.png')

# %%
# Pie chart showing Stroke breakdown
colors = ["grey", "red"]
fig, ax = plt.subplots(figsize=(8,8))
ax.pie(stroke_df["Stroke"].value_counts(),
    labels=stroke_df["Stroke"].value_counts(),
    autopct='%.1f%%',
    colors=colors,
    shadow=True,
    startangle=90,
    counterclock=False)
plt.legend(['Stroke','No Stroke'], loc="best")
plt.title("Stroke Dataset Stroke Breakdown", bbox={'facecolor':'0.8', 'pad':5})

plt.show

# Save figure
plt.savefig('Resources/demo_stroke.png')

# %%
# Distribution plot for Stroke by Gender
sns.displot(stroke_df, x="Gender", hue="Stroke").set(title='Stroke by Gender')

# Save figure
plt.savefig('Resources/stroke_gender.png')

# %%
# Distribution plot for Stroke by Age
sns.displot(stroke_df, x="Age", hue="Stroke", bins=16).set(title='Stroke by Age')

# Save figure
plt.savefig('Resources/stroke_age.png')

# %%
# Distribution plot for Stroke by Hypertension
sns.displot(stroke_df, x="Hypertension", hue="Stroke").set(title='Stroke by Hypertension')

# Save figure
plt.savefig('Resources/stroke_hypertension.png')

# %%
# Distribution plot for Stroke by Heart Disease
sns.displot(stroke_df, x="HeartDisease", hue="Stroke").set(title='Stroke by Heart Disease')

# Save figure
plt.savefig('Resources/stroke_heartdisease.png')

# %%
# Distribution plot for Stroke by Ever Married
sns.displot(stroke_df, x="EverMarried", hue="Stroke").set(title='Stroke by Ever Married')

# Save figure
plt.savefig('Resources/stroke_evermarried.png')

# %%
# Distribution plot for Stroke by Work
sns.displot(stroke_df, x="Work", hue="Stroke").set(title='Stroke by Work')

# Save figure
plt.savefig('Resources/stroke_work.png')

# %%
# Distribution plot for Stroke by Residence
sns.displot(stroke_df, x="Residence", hue="Stroke").set(title='Stroke by Residence')

# Save figure
plt.savefig('Resources/stroke_residence.png')

# %%
# Distribution plot for Stroke by Glucose
sns.displot(stroke_df, x="Glucose", hue="Stroke", bins=[50,75,100,125,150,175,200,225,250]).set(title='Stroke by Glucose')

# Save figure
plt.savefig('Resources/stroke_glucose.png')

# %%
# Distribution plot for Stroke by BMI
sns.displot(stroke_df, x="BMI", hue="Stroke", bins=[0,18.5,25,29.9,40,50,60,70,80,90,100]).set(title='Stroke by BMI')

# Save figure
plt.savefig('Resources/stroke_bmi.png')

# %%
# Distribution plot for Stroke by Smoking
sns.displot(stroke_df, x="Smoking", hue="Stroke").set(title='Stroke by Smoking')

# Save figure
plt.savefig('Resources/stroke_smoking.png')
